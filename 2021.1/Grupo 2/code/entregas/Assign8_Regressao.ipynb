# %% [markdown]
# <a href="https://colab.research.google.com/github/renanalencar/projeto-md-emocoes/blob/main/Assign8_Regressao.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Carregando Drive e pacotes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# importar os pacotes necessários
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Carregando os dados

# %%
dados_tedio_cluster1_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster01_tedio_estresse/dadosTedioB_cluster1.xlsx"
dados_tedio_cluster2_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster02_tedio_estresse/dadosTedioB_cluster2.xlsx"
dados_tedio_cluster3_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster03_tedio_estresse/dadosTedioB_cluster3.xlsx"
dados_tedio_cluster4_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster04_tedio_estresse/dadosTedioB_cluster4.xlsx"
dados_tedio_cluster5_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster05_tedio_estresse/dadosTedioB_cluster5.xlsx"
dados_tedio_cluster6_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster06_tedio_estresse/dadosTedioB_cluster6.xlsx"

dados_estresse_cluster1_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster01_tedio_estresse/dadosEstresseB_cluster1.xlsx"
dados_estresse_cluster2_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster02_tedio_estresse/dadosEstresseB_cluster2.xlsx"
dados_estresse_cluster3_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster03_tedio_estresse/dadosEstresseB_cluster3.xlsx"
dados_estresse_cluster4_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster04_tedio_estresse/dadosEstresseB_cluster4.xlsx"
dados_estresse_cluster5_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster05_tedio_estresse/dadosEstresseB_cluster5.xlsx"
dados_estresse_cluster6_path = "/content/drive/Shareddrives/MINERAÇÃO DE DADOS ENG74291/Database/cluster06_tedio_estresse/dadosEstresseB_cluster6.xlsx"

# %% [markdown]
# ## Tratando os dados
#
# Nessa seção iremos tratar os dados de todos os clusters de perfis de jogadores

# %%
# Criando dataFrames de Tedio
dados_tedio_cluster1 = pd.read_excel(dados_tedio_cluster1_path)
dados_tedio_cluster2 = pd.read_excel(dados_tedio_cluster2_path)
dados_tedio_cluster3 = pd.read_excel(dados_tedio_cluster3_path)
dados_tedio_cluster4 = pd.read_excel(dados_tedio_cluster4_path)
dados_tedio_cluster5 = pd.read_excel(dados_tedio_cluster5_path)
dados_tedio_cluster6 = pd.read_excel(dados_tedio_cluster6_path)

# Criando dataFrames de Estresse
dados_estresse_cluster1 = pd.read_excel(dados_estresse_cluster1_path)
dados_estresse_cluster2 = pd.read_excel(dados_estresse_cluster2_path)
dados_estresse_cluster3 = pd.read_excel(dados_estresse_cluster3_path)
dados_estresse_cluster4 = pd.read_excel(dados_estresse_cluster4_path)
dados_estresse_cluster5 = pd.read_excel(dados_estresse_cluster5_path)
dados_estresse_cluster6 = pd.read_excel(dados_estresse_cluster6_path)

# %% [markdown]
# ### Removendo as dos pontos euclidianos [p1...p24]
#
# > Não são importantes para essa análise

# %%
dados_tedio_cluster1 = dados_tedio_cluster1.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])
dados_tedio_cluster2 = dados_tedio_cluster2.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])
dados_tedio_cluster3 = dados_tedio_cluster3.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])
dados_tedio_cluster4 = dados_tedio_cluster4.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])
dados_tedio_cluster5 = dados_tedio_cluster5.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])
dados_tedio_cluster6 = dados_tedio_cluster6.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])

dados_estresse_cluster1 = dados_estresse_cluster1.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])
dados_estresse_cluster2 = dados_estresse_cluster2.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])
dados_estresse_cluster3 = dados_estresse_cluster3.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])
dados_estresse_cluster4 = dados_estresse_cluster4.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])
dados_estresse_cluster5 = dados_estresse_cluster5.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])
dados_estresse_cluster6 = dados_estresse_cluster6.drop(columns=['p1', 'p2', 'p3', 'p4', 'p5', 'p6', 'p7', 'p8', 'p9', 'p10', 'p11', 'p12', 'p13', 'p14', 'p15', 'p16', 'p17', 'p18', 'p19', 'p20', 'p21', 'p22', 'p23','p24'])

# %% [markdown]
# ### Incluindo valores de cluster

# %%
dados_tedio_cluster1['cluster'] = 1
dados_tedio_cluster2['cluster'] = 2
dados_tedio_cluster3['cluster'] = 3
dados_tedio_cluster4['cluster'] = 4
dados_tedio_cluster5['cluster'] = 5
dados_tedio_cluster6['cluster'] = 6

dados_estresse_cluster1['cluster'] = 1
dados_estresse_cluster2['cluster'] = 2
dados_estresse_cluster3['cluster'] = 3
dados_estresse_cluster4['cluster'] = 4
dados_estresse_cluster5['cluster'] = 5
dados_estresse_cluster6['cluster'] = 6

# %% [markdown]
# ### Incluindo valores de categorização de tedio e estresse

# %%
dados_tedio_cluster1['category'] = 'tedio'
dados_tedio_cluster1['categoryN'] = 'r'
dados_tedio_cluster2['category'] = 'tedio'
dados_tedio_cluster3['category'] = 'tedio'
dados_tedio_cluster4['category'] = 'tedio'
dados_tedio_cluster5['category'] = 'tedio'
dados_tedio_cluster6['category'] = 'tedio'

dados_estresse_cluster1['category'] = 'estresse'
dados_estresse_cluster1['categoryN'] = 'b'
dados_estresse_cluster2['category'] = 'estresse'
dados_estresse_cluster3['category'] = 'estresse'
dados_estresse_cluster4['category'] = 'estresse'
dados_estresse_cluster5['category'] = 'estresse'
dados_estresse_cluster6['category'] = 'estresse'

# %% [markdown]
# ### Concentrando a análise em um único jogo (`game_id == 1`)

# %%
dados_tedio_cluster1 = dados_tedio_cluster1[dados_tedio_cluster1['game_id'] == 1]
dados_tedio_cluster2 = dados_tedio_cluster2[dados_tedio_cluster2['game_id'] == 1]
dados_tedio_cluster3 = dados_tedio_cluster3[dados_tedio_cluster3['game_id'] == 1]
dados_tedio_cluster4 = dados_tedio_cluster4[dados_tedio_cluster4['game_id'] == 1]
dados_tedio_cluster5 = dados_tedio_cluster5[dados_tedio_cluster5['game_id'] == 1]
dados_tedio_cluster6 = dados_tedio_cluster6[dados_tedio_cluster6['game_id'] == 1]

dados_estresse_cluster1 = dados_estresse_cluster1[dados_estresse_cluster1['game_id'] == 1]
dados_estresse_cluster2 = dados_estresse_cluster2[dados_estresse_cluster2['game_id'] == 1]
dados_estresse_cluster3 = dados_estresse_cluster3[dados_estresse_cluster3['game_id'] == 1]
dados_estresse_cluster4 = dados_estresse_cluster4[dados_estresse_cluster4['game_id'] == 1]
dados_estresse_cluster5 = dados_estresse_cluster5[dados_estresse_cluster5['game_id'] == 1]
dados_estresse_cluster6 = dados_estresse_cluster6[dados_estresse_cluster6['game_id'] == 1]

# %% [markdown]
# ### Realizando o merge dos datasets

# %%
frames = [dados_tedio_cluster1, dados_tedio_cluster2, dados_tedio_cluster3, dados_tedio_cluster4, dados_tedio_cluster5, dados_tedio_cluster6, dados_estresse_cluster1, dados_estresse_cluster2, dados_estresse_cluster3, dados_estresse_cluster4, dados_estresse_cluster5, dados_estresse_cluster6]
merged_clusters = pd.concat(frames, ignore_index= True)

# %% [markdown]
# ## Verificando o tamanho do Dataset

# %%
print("Variáveis:\t {}".format(merged_clusters.shape[1]))
print("Entradas:\t {}".format(merged_clusters.shape[0]))
# Out:
# Variáveis:	 13
# Entradas:	 33760

# %% [markdown]
# ## Estatísticas descritivas
#
# - Contagem
# - Média aritimética
# - Desvio padrão
# - Valor mínimo
# - Primeiro quartil, mediana e terceiro quartil
# - Valor máximo

# %%
merged_clusters.describe().round(3)
# Out:
#        game_id       uuid     timestamp  ...  surprised      happy    cluster
# count  33760.0  33760.000  3.376000e+04  ...  33008.000  33008.000  33760.000
# mean       1.0    139.871  1.610458e+12  ...      0.140      0.232      3.472
# std        0.0     73.808  3.989837e+09  ...      0.195      0.268      1.967
# min        1.0      6.000  1.605709e+12  ...      0.000      0.000      1.000
# 25%        1.0     76.000  1.606163e+12  ...      0.014      0.027      1.000
# 50%        1.0    126.000  1.609557e+12  ...      0.054      0.141      4.000
# 75%        1.0    209.000  1.614730e+12  ...      0.186      0.311      5.000
# max        1.0    257.000  1.614818e+12  ...      0.997      1.000      6.000
#
# [8 rows x 10 columns]

# %% [markdown]
# # Matriz de Correlação
#
#  O coeficiente de correlação é uma medida de associação linear entre duas variáveis e situa-se entre -1 e +1. Sendo que -1 indica associação negativa perfeita e +1 indica associação positiva perfeita
#
#  > Utilizando a correlação de Pearson

# %%
merged_clusters.corr().round(3)
# Out:
#            game_id   uuid  timestamp  angry  ...    sad  surprised  happy  cluster
# game_id        NaN    NaN        NaN    NaN  ...    NaN        NaN    NaN      NaN
# uuid           NaN  1.000      0.958 -0.005  ... -0.033     -0.084 -0.012    0.057
# timestamp      NaN  0.958      1.000 -0.002  ... -0.050     -0.081  0.004    0.039
# angry          NaN -0.005     -0.002  1.000  ... -0.311     -0.403 -0.318   -0.063
# disgusted      NaN  0.037      0.028  0.682  ... -0.297     -0.432 -0.003   -0.037
# fear           NaN  0.037      0.034 -0.074  ...  0.235      0.231 -0.223   -0.024
# sad            NaN -0.033     -0.050 -0.311  ...  1.000      0.287 -0.067   -0.110
# surprised      NaN -0.084     -0.081 -0.403  ...  0.287      1.000  0.276   -0.029
# happy          NaN -0.012      0.004 -0.318  ... -0.067      0.276  1.000    0.112
# cluster        NaN  0.057      0.039 -0.063  ... -0.110     -0.029  0.112    1.000
#
# [10 rows x 10 columns]

# %% [markdown]
# # Comportamento da Variável Dependente (Y)
#
# Utilizamos como objeto de análise as emoções

# %% [markdown]
# ## Análises gráficas

# %%
sns.relplot(x = "timestamp", y = "happy", data = merged_clusters, hue = "cluster", style = "category", palette = "plasma")

# %%
sns.relplot(x = "timestamp", y = "angry", data = merged_clusters, hue = "cluster", style = "category", palette = "plasma")

# %%
merged_clusters_indexed = merged_clusters.copy()
merged_clusters_indexed['tempo'] = merged_clusters_indexed.index

sns.relplot(x = "tempo", y = "happy", data = merged_clusters_indexed, hue = "cluster", style = "category", palette = "plasma")

# %%
sns.relplot(x = "tempo", y = "angry", data = merged_clusters_indexed, hue = "cluster", style = "category", palette = "plasma")

# %%
sns.relplot(x = "tempo", y = "disgusted", data = merged_clusters_indexed, hue = "cluster", style = "category", palette = "plasma")

# %%
sns.relplot(x = "tempo", y = "sad", data = merged_clusters_indexed, hue = "cluster", style = "category", palette = "plasma")

# %%
sns.relplot(x = "tempo", y = "fear", data = merged_clusters_indexed, hue = "cluster", style = "category", palette = "plasma")

# %%
sns.relplot(x = "tempo", y = "surprised", data = merged_clusters_indexed, hue = "cluster", style = "category", palette = "plasma")

# %%
cluster1 = pd.concat([dados_tedio_cluster1, dados_estresse_cluster1], ignore_index=True)
cluster1['indice'] = cluster1.index
sns.relplot(x = "indice", y = "happy", data = cluster1, hue = "category", style = "category")

# %%
cluster1.plot.scatter(x='indice', y='happy', c  = 'categoryN')

# %% [markdown]
# ![image.png](data:image/png;base64,...)
